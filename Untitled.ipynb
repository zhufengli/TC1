# %%
import pandas as pd 
from sklearn.utils import shuffle
train_df=pd.read_csv("./train.csv")
train_df=shuffle(train_df)
print (train_df)
# Out:
#           id  feat_1  feat_2  feat_3  feat_4  feat_5  feat_6  feat_7  feat_8  \
# 39500  39501       0       0       6       3       1       0       0       0
# 24568  24569       0       0       0       0       0       0       0       0
# 32243  32244       0       0       1       0       1       0       1       0
# 50521  50522       0       0       0       0       0       0       0       0
# 49979  49980       0       0       0       0       0       0       0       2
# 39669  39670       0       0       0       1       0       0       0       0
# 35096  35097       6       0       0       0       0       0       0       1
# 58268  58269       3       0       1       0       0       0       0       2
# 57591  57592       2       0       0       0       0       0       0       0
# 840      841       2       0       0       0       0       0       0       1
# 52203  52204       2       1       0       0       0       0       2       1
# ...

# %%
#y=train_df['target']
train_df.describe()
# Out:
#                  id       feat_1        feat_2        feat_3        feat_4  \
# count  61878.000000  61878.00000  61878.000000  61878.000000  61878.000000
# mean   30939.500000      0.38668      0.263066      0.901467      0.779081
# std    17862.784315      1.52533      1.252073      2.934818      2.788005
# min        1.000000      0.00000      0.000000      0.000000      0.000000
# 25%    15470.250000      0.00000      0.000000      0.000000      0.000000
# 50%    30939.500000      0.00000      0.000000      0.000000      0.000000
# 75%    46408.750000      0.00000      0.000000      0.000000      0.000000
# max    61878.000000     61.00000     51.000000     64.000000     70.000000
#
#              feat_5        feat_6        feat_7        feat_8        feat_9  \
# count  61878.000000  61878.000000  61878.000000  61878.000000  61878.000000
# mean       0.071043      0.025696      0.193704      0.662433      1.011296
# ...
